# %% [markdown]
# # Module 1 Quiz - Core Syntax
#
# Test your understanding of Python syntax basics. Select the correct answer for each question.

# %%
from jupyterquiz import display_quiz

quiz_data = [
    {
        "question": "What is the correct way to create a variable in Python?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "int age = 10", "correct": False},
            {"answer": "var age = 10", "correct": False},
            {"answer": "age = 10", "correct": True, "feedback": "Correct! Python uses simple assignment without type declarations."},
            {"answer": "age := 10", "correct": False}
        ]
    },
    {
        "question": "Which data type is 'hello'?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "int", "correct": False},
            {"answer": "str", "correct": True, "feedback": "Correct! Text in quotes is a string (str)."},
            {"answer": "bool", "correct": False},
            {"answer": "float", "correct": False}
        ]
    },
    {
        "question": "What is the output of print(3 + 2 * 2)?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "10", "correct": False},
            {"answer": "7", "correct": True, "feedback": "Correct! Multiplication happens before addition (PEMDAS)."},
            {"answer": "5", "correct": False},
            {"answer": "8", "correct": False}
        ]
    },
    {
        "question": "Which collection type stores key-value pairs?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "list", "correct": False},
            {"answer": "tuple", "correct": False},
            {"answer": "dictionary", "correct": True, "feedback": "Correct! Dictionaries store key-value pairs like {'name': 'Jon'}."},
            {"answer": "set", "correct": False}
        ]
    },
    {
        "question": "What will print(len([1,2,3,4])) output?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "3", "correct": False},
            {"answer": "4", "correct": True, "feedback": "Correct! len() returns the number of items in the list."},
            {"answer": "[1,2,3,4]", "correct": False},
            {"answer": "Error", "correct": False}
        ]
    },
    {
        "question": "Which of the following is a Boolean value?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "\"True\"", "correct": False, "feedback": "This is a string, not a Boolean."},
            {"answer": "1", "correct": False},
            {"answer": "True", "correct": True, "feedback": "Correct! True and False (capitalized) are Boolean values."},
            {"answer": "\"False\"", "correct": False}
        ]
    },
    {
        "question": "What symbol starts a comment in Python?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "//", "correct": False},
            {"answer": "#", "correct": True, "feedback": "Correct! The hash symbol starts a single-line comment."},
            {"answer": "<!-- -->", "correct": False},
            {"answer": "/* */", "correct": False}
        ]
    },
    {
        "question": "What does 'if x > 10:' represent?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "A loop", "correct": False},
            {"answer": "A condition", "correct": True, "feedback": "Correct! This is a conditional statement."},
            {"answer": "A function", "correct": False},
            {"answer": "A class", "correct": False}
        ]
    },
    {
        "question": "Which loop iterates over a list directly?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "while", "correct": False},
            {"answer": "if", "correct": False},
            {"answer": "for", "correct": True, "feedback": "Correct! 'for item in list:' iterates directly over items."},
            {"answer": "loop", "correct": False}
        ]
    },
    {
        "question": "What is printed by 'for i in range(3): print(i)'?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "1 2 3", "correct": False},
            {"answer": "0 1 2", "correct": True, "feedback": "Correct! range(3) produces 0, 1, 2."},
            {"answer": "0 1 2 3", "correct": False},
            {"answer": "1 2", "correct": False}
        ]
    }
]

display_quiz(quiz_data)

# %% [markdown]
# ## Short Answer Practice
#
# Try these exercises in your own Python environment:
#
# 1. **Write a line of Python that assigns 42 to variable `answer`.**
#
# 2. **What is the difference between a list and a tuple?**
#
# 3. **Write an if statement that prints "OK" if x > 10.**
#
# 4. **How do you start a comment in Python?**
#
# 5. **Write a loop that prints 1 to 3.**

# %% [markdown]
# ```{admonition} Answers
# :class: dropdown
#
# 1. `answer = 42`
#
# 2. A list is mutable (can be changed); a tuple is immutable (cannot be changed)
#
# 3. ```python
#    if x > 10:
#        print("OK")
#    ```
#
# 4. Use the `#` symbol
#
# 5. ```python
#    for i in range(1, 4):
#        print(i)
#    ```
# ```
